# %%
Name= input("enter your name:")
Clas=int(input("enter your class:"))
Subject1=float(input("enter your marks subject1:"))
Subject2=float(input("enter your marks subject2:"))
Subject3=float(input("enter your marks subject3:"))
Sum= Subject1+ Subject2+ Subject3
Percantage= Sum/300*100
print(f"\n Name: {Name}\n Class:{Clas}\n Subject1: {Subject1}\n Subject2: {Subject2}\n Subject : {Subject3} \n Sum: {Sum} \n Percantage: {Percantage}")
# Out:
#  Name: Bhakti Sharma
#  Class:5
#  Subject1: 70.0
#  Subject2: 80.0
#  Subject : 90.0
#  Sum: 240.0
#  Percantage: 80.0

# %%
str1= input("enter the variable")
str2= input("enter the varible")
result= str1 +" " + str2
print("lower():",result.lower())
print("upper():",result.upper())
print("title():",result.title())
print("swapcase():",result.swapcase())
print("capitalize():",result.capitalize())
print("casefold():",result.casefold())
print("center():",result.center( 40 , "#"))
print("count():",result.count("a"))
print("isalnum():",result.isalnum())
print("isdigit():",result.isdigit())
print("isnumeric():",result.isnumeric())
print("find():",result.find("is"))
print("isspace():",result.isspace())
print("replace():",result.replace(str1,"welcome!"))
print("endswith():",result.endswith(str2))
# Out:
# lower(): python class
# upper(): PYTHON CLASS
# title(): Python Class
# swapcase(): PYTHON CLASS
# capitalize(): Python class
# casefold(): python class
# center(): ##############python class##############
# count(): 1
# isalnum(): False
# isdigit(): False
# isnumeric(): False
# find(): -1
# isspace(): False
# replace(): welcome! class
# endswith(): True
