# %%
name ="bhakti"
type="baddies"
print("name:", name)
print("type:" ,type)
# Out:
# name: bhakti
# type: baddies

# %%
print("hello world", "im using python" ,end="--")
# Out:
# hello world im using python--

# %%
print("hello world", "im using python" ,sep="-")
# Out:
# hello world-im using python

# %%
name= input("enter your name")
print("hey my name is ", name)
# Out:
# hey my name is  bhakti
